# %%
from imageai.Detection.Custom import DetectionModelTrainer

trainer = DetectionModelTrainer()
trainer.setModelTypeAsYOLOv3()
trainer.setDataDirectory(data_directory="galaxies")
trainer.setTrainConfig(object_names_array=["star forming galaxy"], batch_size=4, num_experiments=20, train_from_pretrained_model="pretrained-yolov3.h5")
trainer.trainModel()
# Out:
# Using TensorFlow backend.
# C:\Users\LENOVO\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\LENOVO\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\LENOVO\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
from imageai.Detection.Custom import DetectionModelTrainer

trainer = DetectionModelTrainer()
trainer.setModelTypeAsYOLOv3()
trainer.setDataDirectory(data_directory="galaxies")
metrics = trainer.evaluateModel(model_path="galaxies/models", json_path="galaxies/json/detection_config.json", iou_threshold=0.5, object_threshold=0.3, nms_threshold=0.5)
print(metrics)
# Out:
# Starting Model evaluation....
# C:\Users\LENOVO\anaconda3\lib\site-packages\keras\engine\saving.py:341: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# Model File:  galaxies/models\detection_model-ex-001--loss-0139.314.h5
#
# Using IoU :  0.5
# Using Object Threshold :  0.3
# Using Non-Maximum Suppression :  0.5
# star forming galaxy: 0.0000
# mAP: 0.0000
# ...
# Model File:  galaxies/models\detection_model-ex-002--loss-0116.188.h5
#
# Using IoU :  0.5
# Using Object Threshold :  0.3
# Using Non-Maximum Suppression :  0.5
# star forming galaxy: 0.0001
# mAP: 0.0001
# ...
# Model File:  galaxies/models\detection_model-ex-003--loss-0090.782.h5
#
# Using IoU :  0.5
# Using Object Threshold :  0.3
# Using Non-Maximum Suppression :  0.5
# star forming galaxy: 0.0001
# mAP: 0.0001
# ...
# Model File:  galaxies/models\detection_model-ex-004--loss-0079.083.h5
#
# Using IoU :  0.5
# ...
